# %%
import pandas as pd
df_tw = pd.read_csv(r'C:\Users\afpue\OneDrive\Documentos\GitHub\icare\archivos\df_twitter.csv')

# %%
df_tw.head()
# Out:
#           Author                                            Content  \
# 0      @TReporta  VÍDEO| Reos que no están contagiados con COVID...
# 1     @annytak21  @IvanDuque @jaimepumarejo ya se enteraron de l...
# 2   @ferumapress  El calvario de una familia en Cali por su mamá...
# 3   @hamacazulia  Normas que deberán cumplirse en las empresas, ...
# 4  @cscnoticias1  #Local Gestionan regidores cajas para intubaci...
#
#                   Date Location  Number of Likes  Number of Retweets  \
# 0  2020-06-03 18:56:24      NaN              0.0                 0.0
# 1  2020-06-03 18:56:24      NaN              0.0                 0.0
# 2  2020-06-03 18:56:17      NaN              0.0                 0.0
# 3  2020-06-03 18:56:11      NaN              0.0                 0.0
# 4  2020-06-03 18:56:10      NaN              0.0                 0.0
#
#   In Reply To           Author Name  \
# 0         NaN     Telemetro Reporta
# 1  @IvanDuque        ANNA KAROLYNNA
# ...
