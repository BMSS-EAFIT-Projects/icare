# %%
import pandas as pd
import numpy as np

# %%
ruta_archivo = "/home/afpuertav/mySpace/archivos/tweetsCompletos.xlsx"

xls = pd.ExcelFile(ruta_archivo)
df = pd.concat([xls.parse(hoja) for hoja in xls.sheet_names], ignore_index=True)

# %%
df
# Out:
#                    Author                                            Content  \
# 0        @quepasaraucania  [COVID-19 EN LA ARAUCANÍA 🦠] La Araucanía aman...
# 1             @Digital_58  Alarma en el deporte japones tras confirmarse ...
# 2          @SIPSENOTICIAS  #SNCUN Hasta las 12 horas del 03 de junio, se ...
# 3          @Olivareslucia  #LaPreguntaExacta ¿Qué temas, además de la pan...
# 4           @seleneverar_  * Tania Tinoco a Xavier Vallarino: ¿puede deci...
# ...                   ...                                                ...
# 1442051      @MunicipioEE  Informe N° 265. 15 detenidos en controles en v...
# 1442052             @bbva  ¿Puede transmitirse la #COVID19 a través del a...
# 1442053      @alexlibre18  @HLGatell Ok Hugo, te lo compro. \n\nAhora bie...
# 1442054        @30_marval  Evita reuniones y fiestas durante la emergenci...
# 1442055          @fas1966  @barbarabricenok @carvajaldip @Tono_Coloma @vl...
#
#                         Date Language Location Number of Likes  \
# 0        2020-06-03 18:56:49       es      NaN             0.0
# 1        2020-06-03 18:56:47       es      NaN             0.0
# 2        2020-06-03 18:56:45       es      NaN             0.0
# 3        2020-06-03 18:56:44       es      NaN             0.0
# 4        2020-06-03 18:56:41       es       EC             0.0
# ...                      ...      ...      ...             ...
# 1442051  2020-05-09 13:15:32       es      NaN               1
# 1442052  2020-05-09 13:15:30       es      NaN              10
# 1442053  2020-05-09 13:15:25       es      NaN               0
# 1442054  2020-05-09 13:15:21       es      NaN               0
# 1442055  2020-05-09 13:15:15       es      NaN               0
#
#         Number of Retweets       In Reply To            Author Name  \
# 0                      0.0               NaN     Qué pasa Araucanía
# 1                      0.0               NaN  Noticias Digital58 🇻🇪
# 2                      0.0               NaN         SIPSE NOTICIAS
# 3                      0.0               NaN         Lucía Olivares
# 4                      0.0               NaN         Selene Vera R.
# ...                    ...               ...                    ...
# 1442051                  0               NaN     Esteban Echeverría
# 1442052                  2               NaN                   BBVA
# 1442053                  0         @HLGatell                    LEX
# 1442054                  0               NaN        El profe marval
# 1442055                  1  @barbarabricenok               Fernando
#
#                                         Author Description  ...  \
# 0        Medio independiente, sin tendencia política ni...  ...
# 1        #PeriodismoWebDeVerdad\n✉ prensa@digital58.com...  ...
# 2        Grupo SIPSE empresa líder en información en el...  ...
# 3        Comunicadora. Autora de #SeñoraBruja. Me escuc...  ...
# 4        #Periodista y #Dircom •Sin fines de semana •En...  ...
# ...                                                    ...  ...
# 1442051  Cuenta oficial del Municipio de Esteban Echeve...  ...
# 1442052  Cuestionamos lo establecido, buscamos nuevos c...  ...
# 1442053                              libertad de expresión  ...
# 1442054  NACI EN GDL,REGISTRADO EN LA DELEGACION DE SAN...  ...
# 1442055  PATRIOTA hasta la Medula si no le gusta siga d...  ...
#
#         Author Followers Count Author Listed Count Author Verified Longitude  \
# 0                        235.0                 0.0           False       NaN
# 1                       6264.0                66.0           False       NaN
# 2                      39818.0               281.0           False       NaN
# 3                       1990.0                 9.0           False       NaN
# 4                        316.0                 8.0           False       NaN
# ...                        ...                 ...             ...       ...
# 1442051                   9682                  38           False       NaN
# 1442052                2553881                5711            True       NaN
# 1442053                    136                   0           False       NaN
# 1442054                     81                   0           False       NaN
# 1442055                  16136                  31           False       NaN
#
#         Latitude Sentimiento      Emocion  \
# 0            NaN      1 star       caring
# 1            NaN      1 star  nervousness
# 2            NaN      1 star       caring
# 3            NaN      1 star     approval
# 4            NaN      1 star       caring
# ...          ...         ...          ...
# 1442051      NaN      1 star       caring
# 1442052      NaN      1 star       caring
# 1442053      NaN     5 stars     approval
# 1442054      NaN      1 star       caring
# 1442055      NaN      1 star       caring
#
#                                             Content_limpio nmf_topic_id  \
# 0        covid en la araucanía la araucanía amaneció co...            7
# 1        alarma en el deporte japones tras confirmarse ...            1
# 2        sncun hasta las horas del de junio se han noti...           11
# 3        lapreguntaexacta qué temas además de la pandem...            8
# 4        tania tinoco a xavier vallarino puede decirnos...            4
# ...                                                    ...          ...
# 1442051  informe n detenidos en controles en vía públic...           12
# 1442052  puede transmitirse la covid a través del agua ...            3
# 1442053  hlgatell ok hugo te lo compro ahora bien qué d...            3
# 1442054  evita reuniones y fiestas durante la emergenci...           11
# 1442055  barbarabricenok carvajaldip tonocoloma vladomi...            3
#
#                                         nmf_topic_keywords
# 0                salud ministerio personal pública sistema
# 1            casos nuevos positivos confirmados fallecidos
# 2        personas fallecidas total recuperadas contagiadas
# 3          méxico muertos defunciones confirmados ssaludmx
# 4                     pandemia mundo medio tiempos mundial
# ...                                                    ...
# 1442051              vía youtube españa eluniversalmx cuba
# 1442052               gobierno crisis cuarentena ser ahora
# 1442053               gobierno crisis cuarentena ser ahora
# 1442054  personas fallecidas total recuperadas contagiadas
# 1442055               gobierno crisis cuarentena ser ahora
#
# [1442056 rows x 23 columns]
